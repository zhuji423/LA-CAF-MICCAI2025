# %%
full_data = r"/pub/data/yangdeq/CLIP/data/vein/25_vein_artery/1.ori_data/imagesTr_ori"
semi_data = r"/pub/data/yangdeq/CLIP/data/vein/25_vein_artery/semi_imagesTr_ori"

# %%
import os
import SimpleITK as sitk
full_spacing = []
full_shape = []
for file in os.listdir(full_data):
    img = sitk.ReadImage(os.path.join(full_data, file))
    full_spacing.append(img.GetSpacing()[-1])
    full_shape.append(img.GetSize())
    # print(img.GetSpacing())

# %%
max([i[-1] for i in semi_shape])
# Out:
# 985

# %%
semi_spacing = []
semi_shape = []
for file in os.listdir(semi_data):
    img = sitk.ReadImage(os.path.join(semi_data, file))
    semi_spacing.append(img.GetSpacing()[-1])
    semi_shape.append(img.GetSize())
    # print(img.GetSpacing())

# %%
min(full_spacing), max(full_spacing),min(semi_spacing), max(semi_spacing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 min(full_spacing), max(full_spacing),min(semi_spacing), max(semi_spacing)
#
# NameError: name 'full_spacing' is not defined

# %%
path = r"/pub/data/yangdeq/CLIP/data/vein/25_vein_artery/semi_labelsTr_ori"
import os
import SimpleITK as sitk 
import numpy as np
for i in os.listdir(path):
    img = sitk.ReadImage(os.path.join(path, i))
    arr = sitk.GetArrayFromImage(img)
    arr_unique = np.unique(arr)
    print(arr_unique)
# Out:
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# [0 1 2]
# ...
